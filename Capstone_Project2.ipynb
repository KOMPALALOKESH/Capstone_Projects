# %% [markdown]
# <a href="https://colab.research.google.com/github/KOMPALALOKESH/capstone-projects/blob/main/Capstone_Project2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1 = pd.read_csv('stocks_daily_prices.csv')
df2 = pd.read_csv('stocks_daily_returns.csv')
display(df1)
display(df2)
# Out:
#            Date        AAPL         JPM          PG        UAL
# 0      1/2/2008    5.949703   29.448614   47.058838  29.915234
# 1      1/3/2008    5.952452   29.246094   47.058838  29.690800
# 2      1/4/2008    5.498071   28.582682   46.870098  31.000002
# 3      1/7/2008    5.424478   28.868999   47.175980  29.180000
# 4      1/8/2008    5.229351   27.723747   47.299629  24.389999
# ...         ...         ...         ...         ...        ...
# 3637  6/13/2022  131.880005  115.989998  138.149994  37.020000
# 3638  6/14/2022  132.759995  114.059998  133.839996  36.990002
# 3639  6/15/2022  135.429993  115.410004  132.509995  37.889999
# 3640  6/16/2022  130.059998  113.430000  133.320007  34.779999
# 3641  6/17/2022  131.559998  113.029999  132.360001  36.279999
#
# [3642 rows x 5 columns]
#            Date      AAPL       JPM        PG        UAL
# 0      1/2/2008  0.000000  0.000000  0.000000   0.000000
# 1      1/3/2008  0.046203 -0.687708  0.000000  -0.750233
# 2      1/4/2008 -7.633517 -2.268378 -0.401072   4.409454
# 3      1/7/2008 -1.338518  1.001718  0.652615  -5.870973
# 4      1/8/2008 -3.597157 -3.967066  0.262103 -16.415356
# ...         ...       ...       ...       ...        ...
# 3637  6/13/2022 -3.828484 -2.977838 -2.677001 -10.058308
# 3638  6/14/2022  0.667265 -1.663937 -3.119796  -0.081034
# 3639  6/15/2022  2.011147  1.183593 -0.993725   2.433084
# 3640  6/16/2022 -3.965145 -1.715625  0.611284  -8.207972
# 3641  6/17/2022  1.153314 -0.352642 -0.720077   4.312824
#
# [3642 rows x 5 columns]

# %% [markdown]
# # **Line Plot**

# %%
df1.plot(x='Date',linewidth=0.4,figsize=(12,7))
plt.grid()

# %%
df1.plot(x='Date',y=['AAPL','JPM','PG','UAL'],subplots=True,linewidth=0.5,figsize=(15,15),grid=True)
# plt.legend(loc='upper right')
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f7012d6f4c0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7012d9a1f0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7012d35400>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x7f7012d64520>],
#       dtype=object)

# %%
plt.figure(figsize=(20,4))
plt.subplot(1,4,1)
plt.plot(df1['AAPL'])
plt.title('AAPL')
plt.grid()
plt.subplot(1,4,2)
plt.plot(df1['JPM'])
plt.title('JPM')
plt.grid()
plt.subplot(1,4,3)
plt.plot(df1['PG'])
plt.title('PG')
plt.grid()
plt.subplot(1,4,4)
plt.plot(df1['UAL'])
plt.title('UAL')
plt.grid()

# %%
df2.plot.scatter(x='AAPL',y='JPM')

# %%
sns.scatterplot(x=df2['AAPL'],y=df2['JPM'])

# %%
arr = pd.DataFrame(data={'pct':[70,10,10,10]},index=['AAPL','JPM','PG','UAL'])
arr
# Out:
#       pct
# AAPL   70
# JPM    10
# PG     10
# UAL    10

# %%
arr.plot.pie(y='pct',explode=(0.2,0,0,0),figsize=(12,7),shadow=True)
plt.legend(loc='upper right')

# %%
ualmu = df2['UAL'].mean().round(2)
ualsigma = df2['UAL'].std().round(2)
pgmu = df2['PG'].mean().round(2)
pgsigma = df2['PG'].std().round(2)
df2.plot.hist(bins=40,figsize=(12,7))
plt.title('ualmu:'+str(ualmu)+' ualsigma:'+str(ualsigma)+'  pgmu:'+str(pgmu)+'  pgsigma'+str(pgsigma))
# Out:
# Text(0.5, 1.0, 'ualmu:0.1 ualsigma:4.36  pgmu:0.04  pgsigma1.2')

# %%
correlations = df2.corr()
sns.heatmap(correlations,annot=True)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(111,projection='3d')

x = df2['AAPL'].tolist()
y = df2['JPM'].tolist()
z = df2['UAL'].tolist()

ax.scatter(x,y,z,s=500,c='green',marker='P')

# %%
import plotly.express as px
import plotly.io as pio
fig = px.scatter_3d(data_frame=df2,x='AAPL',y='UAL',z='PG',color='JPM')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7